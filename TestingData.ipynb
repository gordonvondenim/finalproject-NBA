# %%
import pandas as pd
from sklearn.metrics import mean_squared_error, r2_score
scores = "team_boxscore_stats_1997-19.csv"

# %%
scores_df = pd.read_csv(scores)
scores_df['WL'] = scores_df['WL'].map({'W': 1, 'L': 0})
scores_df.head()
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION            TEAM_NAME   GAME_ID  \
# 0      21997  1610612763               VAN  Vancouver Grizzlies  29700014
# 1      21997  1610612742               DAL     Dallas Mavericks  29700014
# 2      21997  1610612741               CHI        Chicago Bulls  29700001
# 3      21997  1610612738               BOS       Boston Celtics  29700001
# 4      21997  1610612766               CHH    Charlotte Hornets  29700006
#
#     GAME_DATE      MATCHUP   WL  MIN  FGM     ...      OREB  DREB  REB  AST  \
# 0  10/31/1997  VAN vs. DAL  0.0  240   36     ...        24    20   44   25
# 1  10/31/1997    DAL @ VAN  1.0  240   32     ...        10    27   37   18
# 2  10/31/1997    CHI @ BOS  0.0  240   33     ...        16    25   41   16
# 3  10/31/1997  BOS vs. CHI  1.0  240   38     ...        22    30   52   18
# 4  10/31/1997  CHH vs. NYK  0.0  240   26     ...        13    29   42   16
#
#    STL  BLK  TOV  PF  PTS  PLUS_MINUS
# ...

# %%
df_2018 = scores_df[49678:52139]
df_2017 = scores_df[47218:49677]
df_2016 = scores_df[44758:47219]
df_2015 = scores_df[42298:44759]
df_2014 = scores_df[39838:42299]
df_2013 = scores_df[37378:39839]
df_2012 = scores_df[34918:37379]
df_2011 = scores_df[32938:34919]
df_2010 = scores_df[30478:32939]

# %%
ratings_2019 = '2019_team_ratings.csv'
ratings_2018 = '2018_team_ratings.csv'
ratings_2017 = '2017_team_ratings.csv'
ratings_2016 = '2016_team_ratings.csv'
ratings_2015 = '2015_team_ratings.csv'
ratings_2014 = '2014_team_ratings.csv'
ratings_2013 = '2013_team_ratings.csv'
ratings_2012 = '2012_team_ratings.csv'
ratings_2011 = '2011_team_ratings.csv'
ratings_2010 = '2010_team_ratings.csv'

# %%
ratings_2019 = pd.read_csv(ratings_2019)
ratings_2018 = pd.read_csv(ratings_2018)
ratings_2017 = pd.read_csv(ratings_2017)                          
ratings_2016 = pd.read_csv(ratings_2016)                          
ratings_2015 = pd.read_csv(ratings_2015)                          
ratings_2014 = pd.read_csv(ratings_2014)
ratings_2013 = pd.read_csv(ratings_2013)                          
ratings_2012 = pd.read_csv(ratings_2012)                          
ratings_2011 = pd.read_csv(ratings_2011)                          
ratings_2010 = pd.read_csv(ratings_2010)

# %%
ratings_2019 = ratings_2019.rename(columns=ratings_2019.iloc[0]).drop(ratings_2019.index[0])
ratings_2018 = ratings_2018.rename(columns=ratings_2018.iloc[0]).drop(ratings_2018.index[0])
ratings_2017 = ratings_2017.rename(columns=ratings_2017.iloc[0]).drop(ratings_2017.index[0])
ratings_2016 = ratings_2016.rename(columns=ratings_2016.iloc[0]).drop(ratings_2016.index[0])
ratings_2015 = ratings_2015.rename(columns=ratings_2015.iloc[0]).drop(ratings_2015.index[0])
ratings_2014 = ratings_2014.rename(columns=ratings_2014.iloc[0]).drop(ratings_2014.index[0])
ratings_2013 = ratings_2013.rename(columns=ratings_2013.iloc[0]).drop(ratings_2013.index[0])
ratings_2012 = ratings_2012.rename(columns=ratings_2012.iloc[0]).drop(ratings_2012.index[0])
ratings_2011 = ratings_2011.rename(columns=ratings_2011.iloc[0]).drop(ratings_2011.index[0])
ratings_2010 = ratings_2010.rename(columns=ratings_2010.iloc[0]).drop(ratings_2010.index[0])

# %%
merged_2019_df = pd.merge(df_2018, ratings_2019, left_on='TEAM_NAME', right_on='Team')
merged_2018_df = pd.merge(df_2017, ratings_2018, left_on='TEAM_NAME', right_on='Team')
merged_2017_df = pd.merge(df_2016, ratings_2017, left_on='TEAM_NAME', right_on='Team')
merged_2016_df = pd.merge(df_2015, ratings_2016, left_on='TEAM_NAME', right_on='Team')
merged_2015_df = pd.merge(df_2014, ratings_2015, left_on='TEAM_NAME', right_on='Team')
merged_2014_df = pd.merge(df_2013, ratings_2014, left_on='TEAM_NAME', right_on='Team')
merged_2013_df = pd.merge(df_2012, ratings_2013, left_on='TEAM_NAME', right_on='Team')
merged_2012_df = pd.merge(df_2011, ratings_2012, left_on='TEAM_NAME', right_on='Team')
merged_2011_df = pd.merge(df_2010, ratings_2011, left_on='TEAM_NAME', right_on='Team')

# %%
merged_2019_df.head()
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION           TEAM_NAME   GAME_ID  \
# 0      22018  1610612755               PHI  Philadelphia 76ers  21800001
# 1      22018  1610612755               PHI  Philadelphia 76ers  21800014
# 2      22018  1610612755               PHI  Philadelphia 76ers  21800029
# 3      22018  1610612755               PHI  Philadelphia 76ers  21800049
# 4      22018  1610612755               PHI  Philadelphia 76ers  21800059
#
#     GAME_DATE      MATCHUP   WL  MIN  FGM   ...      L   W/L%  MOV    ORtg  \
# 0  10/16/2018    PHI @ BOS  0.0  240   34   ...     31  0.622  2.7  113.21
# 1  10/18/2018  PHI vs. CHI  1.0  240   44   ...     31  0.622  2.7  113.21
# 2  10/20/2018  PHI vs. ORL  1.0  240   45   ...     31  0.622  2.7  113.21
# 3  10/23/2018    PHI @ DET  0.0  265   49   ...     31  0.622  2.7  113.21
# 4  10/24/2018    PHI @ MIL  0.0  240   38   ...     31  0.622  2.7  113.21
#
#      DRtg  NRtg  MOV/A  ORtg/A  DRtg/A  NRtg/A▼
# ...

# %%
merged_df = pd.merge(merged_2019_df, merged_2018_df, on='Year', how="inner")
merged_df
# Out:
# Empty DataFrame
# Columns: [SEASON_ID_x, TEAM_ID_x, TEAM_ABBREVIATION_x, TEAM_NAME_x, GAME_ID_x, GAME_DATE_x, MATCHUP_x, WL_x, MIN_x, FGM_x, FGA_x, FG_PCT_x, FG3M_x, FG3A_x, FG3_PCT_x, FTM_x, FTA_x, FT_PCT_x, OREB_x, DREB_x, REB_x, AST_x, STL_x, BLK_x, TOV_x, PF_x, PTS_x, PLUS_MINUS_x, Year, Rk_x, Team_x, Conf_x, Div_x, W_x, L_x, W/L%_x, MOV_x, ORtg_x, DRtg_x, NRtg_x, MOV/A_x, ORtg/A_x, DRtg/A_x, NRtg/A▼, SEASON_ID_y, TEAM_ID_y, TEAM_ABBREVIATION_y, TEAM_NAME_y, GAME_ID_y, GAME_DATE_y, MATCHUP_y, WL_y, MIN_y, FGM_y, FGA_y, FG_PCT_y, FG3M_y, FG3A_y, FG3_PCT_y, FTM_y, FTA_y, FT_PCT_y, OREB_y, DREB_y, REB_y, AST_y, STL_y, BLK_y, TOV_y, PF_y, PTS_y, PLUS_MINUS_y, Rk_y, Team_y, Conf_y, Div_y, W_y, L_y, W/L%_y, MOV_y, ORtg_y, DRtg_y, NRtg_y, MOV/A_y, ORtg/A_y, DRtg/A_y, NRtg/A]
# Index: []
#
# [0 rows x 87 columns]

# %%
y = merged_2019_df['WL'].dropna().values.reshape(-1,1)
x = merged_2019_df[['ORtg', 'NRtg']].astype(float)

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression
model = LogisticRegression()
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y)

model.fit(X_train,y_train)
# Out:
# C:\Users\rossk\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\rossk\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
model.score(X_test, y_test)
# Out:
# 0.6352941176470588

# %%
predicted = model.predict(X)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-125-0c17e27ee292> in <module>
# ----> 1 predicted = model.predict(X)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     211             Returns predicted values.
#     212         """
# --> 213         return self._decision_function(X)
#     214
#     215     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     192
#     193     def _decision_function(self, X):
# --> 194         check_is_fitted(self, "coef_")
#     195
#     196         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     949
# ...
